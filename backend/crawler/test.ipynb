# %%
items_list_url_template = "http://gjcxcy.bjtu.edu.cn/NewLXItemListForStudent.aspx?year={}"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0",
    # cookie is unnecessary
    # "Cookie": "ASP.NET_SessionId=fbp4lickjo3wseqwzl5tj3d5; __AntiXsrfToken=86597a9b04b9418cb177fb9228566bc0"
}

# %%
import requests

items_list_2023_res = requests.get(
    items_list_url_template.format(2023),
    headers=headers,
)
items_list_2023_res.raise_for_status()
type(items_list_2023_res)
# Out:
# requests.models.Response

# %%
from bs4 import BeautifulSoup

items_list_2023_soup = BeautifulSoup(
    items_list_2023_res.text,
    "lxml",
)
type(items_list_2023_soup)
# Out:
# bs4.BeautifulSoup

# %%
"""

items_list_2023_soup = BeautifulSoup(
    items_list_2023_res.text,
    "lxml",
)

我需要的元素都可以用xpath定位到: //tbody/tr

其中一个tr元素形如：

<tr id="goto_tr_863921" class="c--tr">
<td class="c-responsive-detail"><span><i class="fa fa-caret-right"></i></span></td><td>
    202114277043
</td>
<td>
    全域旅游视角下济南市小吃街运营管理和品牌建设研究——基于后疫情时代背景
</td>
<td class="">
    唐瑞腾、张菡、杨焱婷、孙晓
</td>
<td>
    国家级
</td>
<td class="">
    程晓梅、冯梦泽
</td>
<td class="">
    山东青年政治学院
</td>
<td>
    <div class="btn-group btn-group-sm" role="group">
        <a class="btn btn-sm btn-clean btn-icon btn-icon-md" href="NewLXItemListForStudentDetail.aspx?ItemNo=863921&amp;year=2021&amp;type=&amp;IsLXItem=0">
            <span class="c-flex">
                <i class="fa fa-info-circle"></i>
                <span>查看</span>
            </span>
        </a>
    </div>
</td>
</tr>

我需要提取到以下信息, 并存储到一个字典中：

{
    "number": "863921",
    "code": "202114277043",
    "members": [
        "唐瑞腾",
        "张菡",
        "杨焱婷",
        "孙晓"
    ],
    "level": "国家级",
    "teachers": [
        "程晓梅",
        "冯梦泽"
    ],
    "school": "山东青年政治学院"
}

请你提供实现代码

"""

# html was changed by broser dev tools
# trs = items_list_2023_soup.select('tbody tr')
items_list_2023_soup.select('tr:not(thead tr)')[0]
# Out:
# <tr class="c--tr" id="goto_tr_1168324">
# <td>
#                                     202310252057X
#                                 </td>
# <td>
#                                     国内首个重点人群智慧管理与应急疏散系统
#                                 </td>
# <td>
#                                     唐天誉、陈嘉欣、郝思凡、谭梓怡、赵子璇、白逢瑞、陈欣瑶、温莎越
#                                 </td>
# <td>
#                                     国家级
#                                 </td>
# <td>
#                                     房志明、黄中意
#                                 </td>
# <td>
#                                     上海理工大学
#                                 </td>
# <td>
# <div class="btn-group btn-group-sm" role="group">
# <a class="btn btn-sm btn-clean btn-icon btn-icon-md" href="NewLXItemListForStudentDetail.aspx?ItemNo=1168324&amp;year=2023&amp;type=&amp;IsLXItem=0">
# <span class="c-flex">
# <i class="fa fa-info-circle"></i>
# <span>查看</span>
# </span>
# </a>
# </div>
# </td>
# </tr>

# %%
items_list_2023_soup.select('tr:not(thead tr)')[0]['id'].split('_')[-1]
# Out:
# '1168324'

# %%
trs = items_list_2023_soup.select('tr:not(thead tr)')
data_list = []

for tr in trs:
    # 提取编号
    number = tr['id'].split('_')[-1]

    # 提取代码
    code = tr.find_all('td')[0].get_text(strip=True)

    # 提取成员
    members = tr.find_all('td')[2].get_text(strip=True).split('、')

    # 提取级别
    level = tr.find_all('td')[3].get_text(strip=True)

    # 提取指导老师
    teachers = tr.find_all('td')[4].get_text(strip=True).split('、')

    # 提取学校
    school = tr.find_all('td')[5].get_text(strip=True)

    # 构建字典并添加到列表中
    data_list.append({
        "number": number,
        "code": code,
        "members": members,
        "level": level,
        "teachers": teachers,
        "school": school
    })

# 输出结果
data_list
# Out:
# [{'number': '1168324',
#   'code': '202310252057X',
#   'members': ['唐天誉', '陈嘉欣', '郝思凡', '谭梓怡', '赵子璇', '白逢瑞', '陈欣瑶', '温莎越'],
#   'level': '国家级',
#   'teachers': ['房志明', '黄中意'],
#   'school': '上海理工大学'},
#  {'number': '1168323',
#   'code': '202310252028',
#   'members': ['熊浩男', '王宁一', '宋佳乐'],
#   'level': '国家级',
#   'teachers': ['来鑫'],
#   'school': '上海理工大学'},
#  {'number': '1168322',
#   'code': '202310252034',
#   'members': ['陈翔雨迪', '李子瀛', '刘祖安', '周硕', '潘健飞'],
#   'level': '国家级',
#   'teachers': ['吴晨睿'],
#   'school': '上海理工大学'},
#  {'number': '1168321',
#   'code': '202310252068',
#   'members': ['刘若婷', '李家兴', '林洋'],
#   'level': '国家级',
#   'teachers': ['郭宁'],
#   'school': '上海理工大学'},
#  {'number': '1168320',
#   'code': '202310252024',
#   'members': ['岳鑫垒', '程傲', '李钊棱', '朱柏', '张连昊'],
#   'level': '国家级',
#   'teachers': ['王神龙'],
#   'school': '上海理工大学'},
#  {'number': '1168319',
#   'code': '202310252031S',
#   'members': ['房硕', '聂登慧', '梁诗嫣', '禹顺安'],
#   'level': '国家级',
#   'teachers': ['李强'],
#   'school': '上海理工大学'},
#  {'number': '1168318',
#   'code': '202310252025',
#   'members': ['董占彬', '冯一凡', '侯昕睿', '毛渝凯'],
#   'level': '国家级',
#   'teachers': ['吴世青'],
#   'school': '上海理工大学'},
#  {'number': '1167750',
#   'code': '202313613073',
#   'members': ['薛鑫', '徐梦雅', '徐志祥', '吴小龙', '陈广玉'],
#   'level': '国家级',
#   'teachers': ['史谦'],
#   'school': '安徽信息工程学院'},
#  {'number': '1167747',
#   'code': '202310360076S',
#   'members': ['高泽铭'],
#   'level': '国家级',
#   'teachers': ['周建钦'],
#   'school': '安徽工业大学'},
#  {'number': '1167746',
#   'code': '202310360027',
#   'members': ['刘亚鑫', '刘江山', '方明', '刘明智', '罗星语'],
#   'level': '国家级',
#   'teachers': ['杨康'],
#   'school': '安徽工业大学'},
#  {'number': '1167743',
#   'code': '202310360061',
#   'members': ['郏凯旋', '王旭', '石方志', '阚绪锐', '任宇航'],
#   'level': '国家级',
#   'teachers': ['叶晔'],
#   'school': '安徽工业大学'},
#  {'number': '1167742',
#   'code': '202310360075',
#   'members': ['靳宁宁', '周丹丹', '张辉', '刘永浩'],
#   'level': '国家级',
#   'teachers': ['赵帼英', '陶锋'],
#   'school': '安徽工业大学'},
#  {'number': '1167741',
#   'code': '202310360111',
#   'members': ['徐欣玥'],
#   'level': '国家级',
#   'teachers': ['胡根华'],
#   'school': '安徽工业大学'},
#  {'number': '1167740',
#   'code': '202310360060',
#   'members': ['范常春', '于永麟', '张思晗'],
#   'level': '国家级',
#   'teachers': ['黄志来', '冯建有'],
#   'school': '安徽工业大学'},
#  {'number': '1167738',
#   'code': '202310360106',
#   'members': ['江瑞琪'],
#   'level': '国家级',
#   'teachers': ['朱克朋', '徐浩越'],
#   'school': '安徽工业大学'},
#  {'number': '1167737',
#   'code': '202310360015',
#   'members': ['李健辉', '王冰冰', '水畅', '张子良', '吕一帆'],
#   'level': '国家级',
#   'teachers': ['李永涛'],
#   'school': '安徽工业大学'},
#  {'number': '1167735',
#   'code': '202310360063',
#   'members': ['鲁浩然', '程涛', '任鑫柳', '汪加豪', '吕栎'],
#   'level': '国家级',
#   'teachers': ['陈思乐'],
#   'school': '安徽工业大学'},
#  {'number': '1167734',
#   'code': '202310360125S',
#   'members': ['王嘉雯'],
#   'level': '国家级',
#   'teachers': ['戴拥军'],
#   'school': '安徽工业大学'},
#  {'number': '1167732',
#   'code': '202310360026',
#   'members': ['刘颖冲', '吴耀祖', '常帅', '王寿成', '严敏容'],
#   'level': '国家级',
#   'teachers': ['李殿凯', '张义伟'],
#   'school': '安徽工业大学'},
#  {'number': '1167731',
#   'code': '202312926008',
#   'members': ['金泽弘', '宫井府', '彭丹丹', '王磊'],
#   'level': '国家级',
#   'teachers': ['李娜', '王倩南', '张美玲'],
#   'school': '亳州学院'},
#  {'number': '1167730',
#   'code': '202312926005',
#   'members': ['李萌', '毕淑觃', '储雪莲', '代爽', '杜越', '李彤'],
#   'level': '国家级',
#   'teachers': ['刘开放', '刘露'],
#   'school': '亳州学院'},
#  {'number': '1167678',
#   'code': '202312216084X',
#   'members': ['车浩强', '张清远', '张冲', '张毅'],
#   'level': '国家级',
#   'teachers': ['耿丽'],
#   'school': '安徽新华学院'},
#  {'number': '1167677',
#   'code': '202312216001',
#   'members': ['王博', '韩倩倩', '储旋', '徐杰', '朱玉梅', '杨玉娇', '季佳炜', '邓雅文'],
#   'level': '国家级',
#   'teachers': ['章意成'],
#   'school': '安徽新华学院'},
#  {'number': '1167676',
#   'code': '202312216049',
#   'members': ['程克佳'],
#   'level': '国家级',
#   'teachers': ['王婷', '葛桢'],
#   'school': '安徽新华学院'},
#  {'number': '1167675',
#   'code': '202312216043',
#   'members': ['潘慧', '顾多勇', '陈紫嫣', '李雪瑜'],
#   'level': '国家级',
#   'teachers': ['周晶', '许锬'],
#   'school': '安徽新华学院'},
#  {'number': '1167674',
#   'code': '202312216072',
#   'members': ['苏浩阳', '张文宽', '张润', '王帅', '高晨旭'],
#   'level': '国家级',
#   'teachers': ['纪利琴', '王玲燕'],
#   'school': '安徽新华学院'},
#  {'number': '1167673',
#   'code': '202312216046',
#   'members': ['程克佳', '赵文存', '钱妍妍', '姚裕银'],
#   'level': '国家级',
#   'teachers': ['佘月月', '田绮'],
#   'school': '安徽新华学院'},
#  {'number': '1167669',
#   'code': '202312810020',
#   'members': ['李雯', '汪懿如', '吴思雨', '牛朝阳'],
#   'level': '国家级',
#   'teachers': ['张晓东'],
#   'school': '安徽文达信息工程学院'},
#  {'number': '1167668',
#   'code': '202312810029',
#   'members': ['牛朝阳', '李慧', '吴思雨', '李雯', '汪懿如'],
#   'level': '国家级',
#   'teachers': ['张晓东'],
#   'school': '安徽文达信息工程学院'},
#  {'number': '1167667',
#   'code': '202312810024',
#   'members': ['聂琛琛'],
#   'level': '国家级',
#   'teachers': ['孔曼璐'],
#   'school': '安徽文达信息工程学院'}]

# %%
# items_detail_url_template = "https://gjcxcy.bjtu.edu.cn/NewLXItemListForStudentDetail.aspx?ItemNo={}"
# do not use https for 
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
items_detail_url_template = "http://gjcxcy.bjtu.edu.cn/NewLXItemListForStudentDetail.aspx?ItemNo={}"

# %%
from bs4 import BeautifulSoup
items_detail_res = requests.get(
    items_detail_url_template.format(
        data_list[-1]["number"]
    ), 
    headers=headers,
)
items_detail_soup = BeautifulSoup(items_detail_res.text, "lxml")

# %%
items_detail_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><title>
# 	国家级大学生创新创业训练计划平台
# </title>
# <link href="/assets/vendors/base/vendors.bundle.css" rel="stylesheet"/>
# <link href="/assets/site/default/base/style.bundle.css" rel="stylesheet"/>
# <link href="/assets/src/css/Areas/Index/style.css" rel="stylesheet"/>
# <link href="/assets/src/css/framework/change.page.3.0.css" rel="stylesheet"/>
# <link href="/assets/src/css/Areas/Index/_Layout_Index.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#         <script src="/assets/src/js/Areas/Index/Plugins/html5shiv.min.js" type="text/javascript"></script>
#         <script src="/assets/src/js/Areas/Index/Plugins/respond.min.js" type="text/javascript"></script>
#         <![endif]-->
# </head>
# <body>
# <!-- 头部 start -->
# <div class="noselect c-header--state c--header-footer c--page-init-load">
# <div class="container topnav">
# <div id="today">2024年3月1日 星期五</div>
# <div id="jishu">欢迎您！您是第452,338,946个访问者</div>
# </div>
# </div>
# <div class="info-bar-area visible-max c--header-footer c--page-init-load">
# <div class="container">
# <div class="info-bar-inner">
# <div class="logo-wrapper desktop-logo">
# <a class="logo" href="/Index.aspx">
# <span class="webnamecn">国家级大学生创新创业训练计划平台</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- 头部 end -->
# <!-- 菜单 start -->
# <header class="probootstrap-header c--header-footer c--page-init-load" role="banner">
# <div class="container">
# <a class="probootstrap-logo visible-xs" href="/Index.aspx">
# <span class="webnamecn-mobile">国家级大学生创新创业训练计划平台</span>
# </a>
# <a class="probootstrap-burger-menu visible-xs" href="javascript:void(0);"><i class="fa fa-bars"></i></a>
# <div class="mobile-menu-overlay"></div>
# <nav class="probootstrap-nav" role="navigation">
# <ul class="probootstrap-main-nav">
# <li class="first-li li-active" data-index-nav-name="index">
# <a href="/Index.aspx">
# <span>首 页
#                             </span>
# </a>
# <div class="underline"></div>
# </li>
# <li class="first-li" data-index-nav-name="itempagelist">
# <a href="/NewLXItemList.aspx?LXYear=2024">
# <span>历年项目
#                             </span>
# <i class="fa fa-angle-down visible-xs"></i>
# </a>
# <div class="underline"></div>
# <ul class="second-ul">
# <li><a href="/NewLXItemList.aspx?LXYear=2024">2024</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2023">2023</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2022">2022</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2021">2021</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2020">2020</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2019">2019</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2018">2018</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2017">2017</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2016">2016</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2015">2015</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2014">2014</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2013">2013</a></li>
# <li><a href="/NewLXItemList.aspx?LXYear=2012">2012</a></li>
# </ul>
# </li>
# <li class="first-li" data-index-nav-name="jietipagelist">
# <a href="/NewJTItemList.aspx?JTYear=2024">
# <span>结题项目
#                             </span>
# <i class="fa fa-angle-down visible-xs"></i>
# </a>
# <div class="underline"></div>
# <ul class="second-ul">
# <li><a href="/NewJTItemList.aspx?JTYear=2024">2024</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2023">2023</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2022">2022</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2021">2021</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2020">2020</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2019">2019</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2018">2018</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2017">2017</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2016">2016</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2015">2015</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2014">2014</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2013">2013</a></li>
# <li><a href="/NewJTItemList.aspx?JTYear=2012">2012</a></li>
# </ul>
# </li>
# <li class="first-li" data-index-nav-name="niandubaogao">
# <a href="/NianDuBaoGaoProvince.aspx">
# <span>年度进展报告
#                             </span>
# <i class="fa fa-angle-down visible-xs"></i>
# </a>
# <div class="underline"></div>
# <ul class="second-ul">
# <li><a href="/NianDuBaoGaoProvince.aspx">各省、区、市</a></li>
# <li><a href="/NianDuBaoGaoSchool.aspx">中央部委属高校</a></li>
# </ul>
# </li>
# <li class="first-li" data-index-nav-name="noticepagelist">
# <a href="/NoticeBulletinList.aspx">
# <span>通知公告
#                             </span>
# </a>
# <div class="underline"></div>
# </li>
# <li class="first-li" data-index-nav-name="faqpagelist">
# <a href="/InquiryAndAnswerList.aspx">
# <span>咨询问答</span>
# </a>
# <div class="underline"></div>
# </li>
# <li class="first-li" data-index-nav-name="zhengshuchaxunpagelist">
# <a href="/ZhengShuSearch.aspx">
# <span>证书查询</span>
# </a>
# <div class="underline"></div>
# </li>
# </ul>
# <div class="extra-text visible-xs">
# <a class="probootstrap-burger-menu" href="javascript:void(0);"><span class="panelclose"></span></a>
# </div>
# </nav>
# </div>
# </header>
# <form action="./NewLXItemListForStudentDetail.aspx?ItemNo=1167667" class="c-body-container c--body-container c--page-init-load" id="aspnetForm" method="post" name="aspnetForm">
# <div>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <div>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="E0A1E578"/>
# </div>
# <div class="container">
# <div class="bordergray c-page-container">
# <ul class="breadcrumb">
# <li>
# <i class="fa fa-map-marker" style="margin-right: 10px"></i>当前位置 :
#                 </li>
# <li class="li-no-content">
# <a href="/Index.aspx">首页</a>
# </li>
# <li>
# <a href="/NewLXItemList.aspx?LXYear=2024&amp;type=学生查询&amp;IsLXItem=0">历年项目</a>
# </li>
# <li>
# <a href="/NewLXItemListForStudent.aspx?year=2024&amp;type=学生查询&amp;IsLXItem=0">学生查询</a>
# </li>
# <li class="active">“七星”沉浸式立体显示系统—传承红色文化</li>
# </ul>
# <div>
# <div class="c-detail-container">
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>项目编号</label>:
#                         </label>
# <div class="c-detail-item">
#                             202312810024
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>项目名称</label>:
#                         </label>
# <div class="c-detail-item">
#                             “七星”沉浸式立体显示系统—传承红色文化
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>项目类型</label>:
#                         </label>
# <div class="c-detail-item">
#                             创业训练项目
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>项目类别</label>:
#                         </label>
# <div class="c-detail-item">
#                             一般项目
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>重点支持领域</label>:
#                         </label>
# <div class="c-detail-item">
# </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>所属学校</label>:
#                         </label>
# <div class="c-detail-item">
#                             安徽文达信息工程学院
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>项目实施时间</label>:
#                         </label>
# <div class="c-detail-item">
#                             0001-01-01 至 0001-01-01
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>所属学科门类</label>:
#                         </label>
# <div class="c-detail-item">
#                             艺术学
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>所属专业大类</label>:
#                         </label>
# <div class="c-detail-item">
#                             艺术学理论类
#                         </div>
# </div>
# <div class="form-group form-group-line">
# <label class="c-label-title">
# <label>立项时间</label>:
#                         </label>
# <div class="c-detail-item">
#                             2023-10-10
#                         </div>
# </div>
# <div class="form-group">
# <label class="c-label-title">
# <label>项目成员</label>:
#                         </label>
# <div class="c-detail-item">
# <div class="c-table-responsive-container">
# <table class="table table-hover c-table-members table_vertical-middle" data-responsive-mode="open">
# <thead>
# <tr>
# <th style="min-width: 100px;">姓名</th>
# <th style="min-width: 100px;">年级</th>
# <th style="min-width: 100px;">学号</th>
# <th style="min-width: 100px;">所在院系</th>
# <th style="min-width: 100px;">专业</th>
# <th style="min-width: 100px;">联系电话</th>
# <th style="min-width: 100px;">E-mail</th>
# <th style="min-width: 100px;">是否主持人</th>
# </tr>
# </thead>
# <tbody>
# <tr class="c--tr">
# <td>聂琛琛</td>
# <td>
#                                                 *
#                                             </td>
# <td>1940601129</td>
# <td>
#                                                 *</td>
# <td>
#                                                 *</td>
# <td>
#                                                 *</td>
# <td>
#                                                 *</td>
# <td>第一主持人</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="form-group">
# <label class="c-label-title">
# <label>指导教师</label>:
#                         </label>
# <div class="c-detail-item">
# <div class="c-table-responsive-container">
# <table class="table table-hover c-table-members table_vertical-middle" data-responsive-mode="open">
# <thead>
# <tr>
# <th style="min-width: 100px;">姓名</th>
# <th style="min-width: 200px;">单位</th>
# <th style="min-width: 120px;">专业技术职务</th>
# <th style="min-width: 120px;">指导教师类型</th>
# </tr>
# </thead>
# <tbody>
# <tr class="c--tr">
# <td>孔曼璐</td>
# <td></td>
# <td>讲师</td>
# <td>第一指导教师</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="c-more-search-condition" style="margin-top: 15px;">
# <div class="accordion accordion-toggle-arrow c-accordion--detail" id="c_more_search_condition__accordion">
# <div class="card">
# <div class="card-header noselect">
# <div aria-expanded="false" class="card-title collapsed" data-target="#c_more_search_condition__accordion_1" data-toggle="collapse">
# <span class="c-turn c-turn-on">
# <span>项目信息<span class="openstate">[展开]</span></span>
# <i class="la la-angle-down"></i>
# </span>
# <span class="c-turn c-turn-off">
# <span>项目信息<span class="openstate">[收起]</span></span>
# <i class="la la-angle-up"></i>
# </span>
# </div>
# </div>
# <div class="collapse" data-parent="#c_more_search_condition__accordion" id="c_more_search_condition__accordion_1">
# <div class="card-body">
# <div class="search-form-content">
# <table class="table table-bordered infotable">
# <tr>
# <td class="labbelbg">负责人曾经参与科研的情况：</td>
# <td></td>
# </tr>
# <tr>
# <td class="labbelbg">指导教师承担科研课题情况：</td>
# <td></td>
# </tr>
# <tr>
# <td class="labbelbg">企业导师担任的职务及科研情况：</td>
# <td></td>
# </tr>
# <tr>
# <td class="labbelbg">指导教师、企业导师支持情况：</td>
# <td><br/></td>
# </tr>
# <tr>
# <td class="labbelbg">项目简介：</td>
# <td>
#                                                         本项目开创了沉浸式红色文化立体显示体验,客观的加强了资源的保护和利用,本项目响应了国家对红色文化遗产进行保护与修复政策,带动红色文化进行融合发展政策,进一步提升了红色文化的传播品质,带动红色文化崛起,具有社会责任感,让体验者体验红色文化精神,不忘初心,牢记历史。
#                                                     </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- footer start -->
# <footer class="footer-area c--header-footer c--page-init-load c--footer">
# <div class="footer-top padding-top-50 padding-bottom-40">
# <div class="container">
# <div class="footer-container">
# <span class="c-footer-part">
# <span class="footer-title">服务电话：</span>
# <span class="footer-content">025-83215097 400-050-8066
#                             </span>
# </span>
# <span class="c-footer-part">
# <span class="footer-title">备案号：</span>
# <span class="footer-content">BJTUICP备 14070101
#                             </span>
# </span>
# </div>
# </div>
# </div>
# </footer>
# <!-- footer end -->
# </form>
# <!-- 返回顶部 start -->
# <div class="back-to-top c--page-init-load">
# <span class="back-top"><i class="fa fa-angle-up"></i></span>
# </div>
# <!-- 返回顶部 end -->
# <div class="hidden c-page-global-data">
# <global-data class="hidden" data-name="_page_areas" data-value=""></global-data><global-data class="hidden" data-name="_page_controller" data-value="index"></global-data><global-data class="hidden" data-name="_page_action" data-value="itempagelist"></global-data>
# </div>
# <div class="hidden c-page-global-root-data"></div>
# <script src="/assets/vendors/base/vendors.bundle.js" type="text/javascript"></script>
# <script src="/assets/site/default/base/scripts.bundle.js" type="text/javascript"></script>
# <script src="/assets/src/js/Areas/Index/Plugins/jquery.flexslider-min.js" type="text/javascript"></script>
# <script src="/assets/src/js/change-site.js" type="text/javascript"></script>
# <script src="/assets/src/js/framework/change.page.3.0.js" type="text/javascript"></script>
# <script src="/assets/src/js/Areas/Index/_Layout_Index.js" type="text/javascript"></script>
# </body>
# </html>

# %%
# labels tag: //div/label/label
# about following-sibling: https://blog.csdn.net/weixin_44090305/article/details/92185565
# values tag: //div/label/label/../following-sibling::div

labels = [
    item for item in
    items_detail_soup.select('div > label > label')
    if (
        "指导教师" not in item.text.strip() and
        "项目成员" not in item.text.strip()
    )
]
values = [
    label.parent.find_next_sibling('div')
    for label in labels
]
print([tag.text.strip() for tag in labels])
print([tag.text.strip() for tag in values])
# Out:
# ['项目编号', '项目名称', '项目类型', '项目类别', '重点支持领域', '所属学校', '项目实施时间', '所属学科门类', '所属专业大类', '立项时间']
# ['202312810024', '“七星”沉浸式立体显示系统—传承红色文化', '创业训练项目', '一般项目', '', '安徽文达信息工程学院', '0001-01-01 至 0001-01-01', '艺术学', '艺术学理论类', '2023-10-10']

# %%
# tables: //table
import pandas as pd

tables = items_detail_soup.find_all('table')
members_detail = tables[0]
teachers_detail = tables[1]
notes = tables[-1]

# %%
# Out:
# '<table class="table table-hover c-table-members table_vertical-middle" data-responsive-mode="open">\n<thead>\n<tr>\n<th style="min-width: 100px;">姓名</th>\n<th style="min-width: 100px;">年级</th>\n<th style="min-width: 100px;">学号</th>\n<th style="min-width: 100px;">所在院系</th>\n<th style="min-width: 100px;">专业</th>\n<th style="min-width: 100px;">联系电话</th>\n<th style="min-width: 100px;">E-mail</th>\n<th style="min-width: 100px;">是否主持人</th>\n</tr>\n</thead>\n<tbody>\n<tr class="c--tr">\n<td>聂琛琛</td>\n<td>\r\n                                                *\r\n                                            </td>\n<td>1940601129</td>\n<td>\r\n                                                *</td>\n<td>\r\n                                                *</td>\n<td>\r\n                                                *</td>\n<td>\r\n                                                *</td>\n<td>第一主持人</td>\n</tr>\n</tbody>\n</table>'

# %%
from io import StringIO

tables = pd.read_html(StringIO(items_detail_res.text), flavor="lxml")
tables = [table.fillna("") for table in tables]

# %%
tables[0]
# Out:
#     姓名 年级          学号 所在院系 专业 联系电话 E-mail  是否主持人
# 0  聂琛琛  *  1940601129    *  *    *      *  第一主持人

# %%
tables[1]
# Out:
#     姓名 单位 专业技术职务  指导教师类型
# 0  孔曼璐        讲师  第一指导教师

# %%
tables[0].to_dict(orient='records')
# Out:
# [{'姓名': '聂琛琛',
#   '年级': '*',
#   '学号': 1940601129,
#   '所在院系': '*',
#   '专业': '*',
#   '联系电话': '*',
#   'E-mail': '*',
#   '是否主持人': '第一主持人'}]

# %%
tables[2]
# Out:
#                  0                                                  1
# 0    负责人曾经参与科研的情况：
# 1    指导教师承担科研课题情况：
# 2  企业导师担任的职务及科研情况：
# 3   指导教师、企业导师支持情况：
# 4            项目简介：  本项目开创了沉浸式红色文化立体显示体验,客观的加强了资源的保护和利用,本项目响应了国家对红色...

# %%
"""
对于这样的一个pd.DataFrame
	0	1
0	负责人曾经参与科研的情况：	
1	指导教师承担科研课题情况：	
2	企业导师担任的职务及科研情况：	
3	指导教师、企业导师支持情况：	
4	项目简介：	本项目开创了...

如何将它变成：
{
    "负责人曾经参与科研的情况": "",
    "指导教师承担科研课题情况": "",
    "企业导师担任的职务及科研情况": "",
    "指导教师、企业导师支持情况": "",
    "项目简介": "本项目开创了..."
}
"""
df = tables[2]
# 将第一列设置为索引，并去掉末尾的冒号
df[0] = df[0].str.rstrip('：')

# 将 DataFrame 转换为字典
df.set_index(0)[1].to_dict()
# Out:
# {'负责人曾经参与科研的情况': '',
#  '指导教师承担科研课题情况': '',
#  '企业导师担任的职务及科研情况': '',
#  '指导教师、企业导师支持情况': '',
#  '项目简介': '本项目开创了沉浸式红色文化立体显示体验,客观的加强了资源的保护和利用,本项目响应了国家对红色文化遗产进行保护与修复政策,带动红色文化进行融合发展政策,进一步提升了红色文化的传播品质,带动红色文化崛起,具有社会责任感,让体验者体验红色文化精神,不忘初心,牢记历史。'}
